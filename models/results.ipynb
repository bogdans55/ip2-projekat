# %%
import myfunctions as mf
import pandas as pd

# %%
results = pd.DataFrame()

# %%
results = pd.concat([results, mf.write_results('10x', ['B', 'M', 'NK', 'T'])], ignore_index=True)
# Out:
# Matrica konfuzije:
#  [[ 2951     0     0     0]
#  [    3   529     0     5]
#  [    0     1  2392    24]
#  [    3     2     2 18817]]
# Accuracy score:  0.9983824659306887
# Precision score:  0.9983824100305962
# Recall score:  0.9983824659306887
# F1 score:  0.9983793640861736
# Matrica konfuzije:
#  [[ 9457     0     0   268]
#  [   59  1617     0   172]
#  [    0     0   855  7324]
#  [   32     1     1 62642]]
# Accuracy score:  0.9046804483913233
# Precision score:  0.9148959014596477
# Recall score:  0.9046804483913233
# F1 score:  0.8713012002027559
# Matrica konfuzije:
#  [[ 2951     0     0     0]
#  [    3   529     0     5]
#  [    0     1  2392    24]
#  [    3     2     2 18817]]
# Accuracy score:  0.9983824659306887
# Precision score:  0.9983824100305962
# Recall score:  0.9983824659306887
# F1 score:  0.9983793640861736
# e:\Projekti\ip2-projekat\models\myfunctions.py:24: RuntimeWarning: invalid value encountered in divide
# ...

# %%
results = pd.concat([results, mf.write_results('BS2', ['B', 'D', 'M', 'NK', 'T'])], ignore_index=True)
# Out:
# Matrica konfuzije:
#  [[ 581    0    0    0   10]
#  [   3   58   16    0    3]
#  [   0    0  596    0    0]
#  [   0    0    0   91  179]
#  [   1    0    1    0 2105]]
# Accuracy score:  0.9415477497255763
# Precision score:  0.9460241522806416
# Recall score:  0.9415477497255763
# F1 score:  0.9300595220686078
# Matrica konfuzije:
#  [[1713    0    0    0  164]
#  [ 167    0   22    0   81]
#  [  13    0 1459    0  534]
#  [   0    0    0   46  796]
#  [   4    0    0    2 7145]]
# Accuracy score:  0.8532027004775234
# Precision score:  0.851099079171363
# Recall score:  0.8532027004775234
# F1 score:  0.8157644229453747
# Matrica konfuzije:
#  [[ 581    0    0    0   10]
#  [   3   58   16    0    3]
#  [   0    0  596    0    0]
#  [   0    0    0   91  179]
#  [   1    0    1    0 2105]]
# Accuracy score:  0.9415477497255763
# Precision score:  0.9460241522806416
# Recall score:  0.9415477497255763
# F1 score:  0.9300595220686078
# Matrica konfuzije:
# ...

# %%
results = pd.concat([results, mf.write_results('GEO', ['B', 'M', 'NK', 'T'])], ignore_index=True)
# Out:
# Matrica konfuzije:
#  [[ 424    8    0   84]
#  [   0  257    0    6]
#  [   0    0   20   59]
#  [   1   20    0 4043]]
# Accuracy score:  0.9638358390898009
# Precision score:  0.9651558114957991
# Recall score:  0.9638358390898009
# F1 score:  0.9597567434429397
# Matrica konfuzije:
#  [[ 1360   103    25   268]
#  [    3   835     0    18]
#  [    0     0    31   278]
#  [  173   108    21 13182]]
# Accuracy score:  0.939225845778726
# Precision score:  0.9322323142208868
# Recall score:  0.939225845778726
# F1 score:  0.9330858359759505
# Matrica konfuzije:
#  [[ 424    8    0   84]
#  [   0  257    0    6]
#  [   0    0   20   59]
#  [   1   20    0 4043]]
# Accuracy score:  0.9638358390898009
# Precision score:  0.9651558114957991
# Recall score:  0.9638358390898009
# F1 score:  0.9597567434429397
# e:\Projekti\ip2-projekat\models\myfunctions.py:24: RuntimeWarning: invalid value encountered in divide
#   normalized_conf_matrix = cm / class_sums[:, np.newaxis]
# ...

# %%
results.to_csv('../data/results.csv', index=False)
